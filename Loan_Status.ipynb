# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
df=pd.read_csv(r"train_ctrUa4K.csv")

# %%
df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            614 non-null    object
#  1   Gender             601 non-null    object
#  2   Married            611 non-null    object
#  3   Dependents         599 non-null    object
#  4   Education          614 non-null    object
#  5   Self_Employed      582 non-null    object
#  6   ApplicantIncome    614 non-null    int64
#  7   CoapplicantIncome  614 non-null    float64
#  8   LoanAmount         592 non-null    float64
#  9   Loan_Amount_Term   600 non-null    float64
#  10  Credit_History     564 non-null    float64
#  11  Property_Area      614 non-null    object
#  12  Loan_Status        614 non-null    object
# dtypes: float64(4), int64(1), object(8)
# memory usage: 62.5+ KB

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.isna().sum()
# Out:
# Loan_ID               0
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
df["Loan_Status"].unique()
# Out:
# array(['Y', 'N'], dtype=object)

# %%
df["Credit_History"].unique()
# Out:
# array([ 1.,  0., nan])

# %%
df["Loan_Amount_Term"].unique()
# Out:
# array([360., 120., 240.,  nan, 180.,  60., 300., 480.,  36.,  84.,  12.])

# %%
df.describe()
# Out:
#        ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count       614.000000         614.000000  592.000000         600.00000
# mean       5403.459283        1621.245798  146.412162         342.00000
# std        6109.041673        2926.248369   85.587325          65.12041
# min         150.000000           0.000000    9.000000          12.00000
# 25%        2877.500000           0.000000  100.000000         360.00000
# 50%        3812.500000        1188.500000  128.000000         360.00000
# 75%        5795.000000        2297.250000  168.000000         360.00000
# max       81000.000000       41667.000000  700.000000         480.00000
#
#        Credit_History
# count      564.000000
# mean         0.842199
# std          0.364878
# min          0.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max          1.000000

# %%
df = df.drop(columns=['Loan_ID'])

# %%
categorical_columns = ['Gender', 'Married', 'Dependents', 'Education', 'Self_Employed', 'Property_Area','Loan_Status','Credit_History']
print(categorical_columns)
# Out:
# ['Gender', 'Married', 'Dependents', 'Education', 'Self_Employed', 'Property_Area', 'Loan_Status', 'Credit_History']

# %%
numerical_columns = ['ApplicantIncome', 'CoapplicantIncome', 'LoanAmount','Loan_Amount_Term']
print(numerical_columns)
# Out:
# ['ApplicantIncome', 'CoapplicantIncome', 'LoanAmount', 'Loan_Amount_Term']

# %%
df['Loan_Status'].value_counts()
# Out:
# Y    422
# N    192
# Name: Loan_Status, dtype: int64

# %%
plt.figure(figsize=(10, 6))
sns.countplot(x='Loan_Status', data=df)
plt.title('CountPlot of "Loan_Status" Feature in Dataset', fontsize=14, c='k')
plt.xlabel('Loan_Status', fontsize=14, c='k')
plt.ylabel('Counts', fontsize=14, c='k')
# Out:
# Text(0, 0.5, 'Counts')

# %%
df['Gender'].value_counts()
# Out:
# Male      489
# Female    112
# Name: Gender, dtype: int64

# %%
plt.figure(figsize=(10, 6))
sns.countplot(x='Gender', data=df)
plt.title('CountPlot of "Gender" Feature in Dataset', fontsize=14, c='k')
plt.xlabel('Gender', fontsize=14, c='k')
plt.ylabel('Counts', fontsize=14, c='k')
# Out:
# Text(0, 0.5, 'Counts')

# %%
df['Married'].value_counts()
# Out:
# Yes    398
# No     213
# Name: Married, dtype: int64

# %%
plt.figure(figsize=(10, 6))
sns.countplot(x='Married', data=df)
plt.title('CountPlot of "Married" Feature in Dataset', fontsize=14, c='k')
plt.xlabel('Married', fontsize=14, c='k')
plt.ylabel('Counts', fontsize=14, c='k')
# Out:
# Text(0, 0.5, 'Counts')

# %%
df['Dependents'].value_counts()
# Out:
# 0     345
# 1     102
# 2     101
# 3+     51
# Name: Dependents, dtype: int64

# %%
plt.figure(figsize=(10, 6))
sns.countplot(x='Dependents', data=df)
plt.title('CountPlot of "Dependents" Feature in Dataset', fontsize=14, c='k')
plt.xlabel('Dependents', fontsize=14, c='k')
plt.ylabel('Counts', fontsize=14, c='k')
# Out:
# Text(0, 0.5, 'Counts')

# %%
df['Education'].value_counts()
# Out:
# Graduate        480
# Not Graduate    134
# Name: Education, dtype: int64

# %%
plt.figure(figsize=(10, 6))
sns.countplot(x='Education', data=df)
plt.title('CountPlot of "Education" Feature in Dataset', fontsize=14, c='k')
plt.xlabel('Education', fontsize=14, c='k')
plt.ylabel('Counts', fontsize=14, c='k')
# Out:
# Text(0, 0.5, 'Counts')

# %%
df['Self_Employed'].value_counts()
# Out:
# No     500
# Yes     82
# Name: Self_Employed, dtype: int64

# %%
plt.figure(figsize=(10, 6))
sns.countplot(x='Self_Employed', data=df)
plt.title('CountPlot of "Self_Employed" Feature in Dataset', fontsize=14, c='k')
plt.xlabel('Self_Employed', fontsize=14, c='k')
plt.ylabel('Counts', fontsize=14, c='k')
# Out:
# Text(0, 0.5, 'Counts')

# %%
df['Property_Area'].value_counts()
# Out:
# Semiurban    233
# Urban        202
# Rural        179
# Name: Property_Area, dtype: int64

# %%
plt.figure(figsize=(10, 6))
sns.countplot(x='Property_Area', data=df)
plt.title('CountPlot of "Property_Area" Feature in Dataset', fontsize=14, c='k')
plt.xlabel('Property_Area', fontsize=14, c='k')
plt.ylabel('Counts', fontsize=14, c='k')
# Out:
# Text(0, 0.5, 'Counts')

# %%
df.hist(bins=30, figsize=(20, 10))
plt.show()

# %%
## Scatterplot with important Feature (ApplicantIncome) with the target (LoanAmount)
plt.figure(figsize=(10, 6))
plt.scatter(df['ApplicantIncome'], df['LoanAmount'], alpha=0.4)
plt.title('Distribution of ApplicantIncome with LoanAmount', fontsize=14, c='k')
plt.xlabel('ApplicantIncome', fontsize=14, c='k')
plt.ylabel('LoanAmount', fontsize=14, c='k')
plt.show()

# %%
## Scatterplot with important Feature (CoapplicantIncome) with the target (LoanAmount)
plt.figure(figsize=(10, 6))
plt.scatter(df['CoapplicantIncome'], df['LoanAmount'], alpha=0.4)
plt.title('Distribution of CoapplicantIncome with LoanAmount', fontsize=14, c='k')
plt.xlabel('CoapplicantIncome', fontsize=14, c='k')
plt.ylabel('LoanAmount', fontsize=14, c='k')
plt.show()

# %%
## Scatterplot with (ApplicantIncome) & (CoapplicantIncome) at each (Loan_Status)
sns.relplot(y='ApplicantIncome', x='Loan_Status', data=df, kind='scatter'
             )
plt.show()

# %%
## Scatterplot with (ApplicantIncome) & (CoapplicantIncome) at each (Loan_Status)
sns.relplot(y='CoapplicantIncome', x='Loan_Status', data=df, kind='scatter'
             )
plt.show()

# %%
## Check the BoxPlot of the (median_income) at different Categories of (ocean_proximity)
plt.figure(figsize=(10, 6))
sns.boxplot(y='ApplicantIncome', data=df, x='Loan_Status')
plt.title('Boxplot of ApplicantIncome at different "Loan_Status" Categories', fontsize=14, c='k')
plt.xlabel('Loan_Status', fontsize=14, c='k')
plt.ylabel('ApplicantIncome', fontsize=14, c='k')
plt.show()

# %%
fig,axes = plt.subplots(1,4,figsize=(20,10))
for idx,cat_col in enumerate(numerical_columns):
    sns.boxplot(y=cat_col,data=df,x='Loan_Status',ax=axes[idx])

print(df[numerical_columns].describe())
plt.subplots_adjust(hspace=1)
# Out:
#        ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term
# count       614.000000         614.000000  592.000000         600.00000
# mean       5403.459283        1621.245798  146.412162         342.00000
# std        6109.041673        2926.248369   85.587325          65.12041
# min         150.000000           0.000000    9.000000          12.00000
# 25%        2877.500000           0.000000  100.000000         360.00000
# 50%        3812.500000        1188.500000  128.000000         360.00000
# 75%        5795.000000        2297.250000  168.000000         360.00000
# max       81000.000000       41667.000000  700.000000         480.00000

# %%
df.head()
# Out:
#   Gender Married Dependents     Education Self_Employed  ApplicantIncome  \
# 0   Male      No          0      Graduate            No             5849
# 1   Male     Yes          1      Graduate            No             4583
# 2   Male     Yes          0      Graduate           Yes             3000
# 3   Male     Yes          0  Not Graduate            No             2583
# 4   Male      No          0      Graduate            No             6000
#
#    CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History  \
# 0                0.0         NaN             360.0             1.0
# 1             1508.0       128.0             360.0             1.0
# 2                0.0        66.0             360.0             1.0
# 3             2358.0       120.0             360.0             1.0
# 4                0.0       141.0             360.0             1.0
#
#   Property_Area Loan_Status
# 0         Urban           Y
# 1         Rural           N
# 2         Urban           Y
# ...

# %%
df['Dependents'].replace('3+','3',inplace=True)
df['Loan_Status'].replace('N', 0,inplace=True)
df['Loan_Status'].replace('Y', 1,inplace=True)

# %%
plt.figure(figsize=(12, 6))
sns.heatmap(df.corr(), annot=True, cmap='Blues', fmt='.2f')  ## symmetric matrix
plt.show()

# %%
df
# Out:
#      Gender Married Dependents     Education Self_Employed  ApplicantIncome  \
# 0      Male      No          0      Graduate            No             5849
# 1      Male     Yes          1      Graduate            No             4583
# 2      Male     Yes          0      Graduate           Yes             3000
# 3      Male     Yes          0  Not Graduate            No             2583
# 4      Male      No          0      Graduate            No             6000
# ..      ...     ...        ...           ...           ...              ...
# 609  Female      No          0      Graduate            No             2900
# 610    Male     Yes          3      Graduate            No             4106
# 611    Male     Yes          1      Graduate            No             8072
# 612    Male     Yes          2      Graduate            No             7583
# 613  Female      No          0      Graduate           Yes             4583
#
# ...

# %%
df.groupby("Gender")["Loan_Status"].mean()
# Out:
# Gender
# Female    0.669643
# Male      0.693252
# Name: Loan_Status, dtype: float64

# %%
pd.pivot_table(data=df,index="Credit_History",columns="Gender",values='ApplicantIncome')
# Out:
# Gender               Female         Male
# Credit_History
# 0.0             3804.411765  6253.188406
# 1.0             5013.488095  5323.400524

# %%
df.groupby("Loan_Status")['ApplicantIncome'].mean()
# Out:
# Loan_Status
# 0    5446.078125
# 1    5384.068720
# Name: ApplicantIncome, dtype: float64

# %%
pd.pivot_table(data=df,index='Loan_Status',columns='Property_Area',values='ApplicantIncome')
# Out:
# Property_Area        Rural    Semiurban        Urban
# Loan_Status
# 0              6497.521739  5296.851852  4511.420290
# 1              4962.290909  5290.877095  5858.330827

# %%
df.groupby("Loan_Status")['ApplicantIncome'].mean()
# Out:
# Loan_Status
# 0    5446.078125
# 1    5384.068720
# Name: ApplicantIncome, dtype: float64

# %%
df['ApplicantIncome'].unique().min()
# Out:
# 150

# %%
df['ApplicantIncome'].unique().max()
# Out:
# 81000

# %%
df['CoapplicantIncome'].head(20)
# Out:
# 0         0.0
# 1      1508.0
# 2         0.0
# 3      2358.0
# 4         0.0
# 5      4196.0
# 6      1516.0
# 7      2504.0
# 8      1526.0
# 9     10968.0
# 10      700.0
# 11     1840.0
# 12     8106.0
# 13     2840.0
# 14     1086.0
# 15        0.0
# 16        0.0
# 17        0.0
# 18        0.0
# 19     3500.0
# Name: CoapplicantIncome, dtype: float64

# %%
df
# Out:
#      Gender Married Dependents     Education Self_Employed  ApplicantIncome  \
# 0      Male      No          0      Graduate            No             5849
# 1      Male     Yes          1      Graduate            No             4583
# 2      Male     Yes          0      Graduate           Yes             3000
# 3      Male     Yes          0  Not Graduate            No             2583
# 4      Male      No          0      Graduate            No             6000
# ..      ...     ...        ...           ...           ...              ...
# 609  Female      No          0      Graduate            No             2900
# 610    Male     Yes          3      Graduate            No             4106
# 611    Male     Yes          1      Graduate            No             8072
# 612    Male     Yes          2      Graduate            No             7583
# 613  Female      No          0      Graduate           Yes             4583
#
# ...

# %%
df['Loan_Status'].unique()
# Out:
# array([1, 0])

# %%
from sklearn.linear_model import LinearRegression
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from xgboost import XGBRegressor
from sklearn.preprocessing import  RobustScaler
from sklearn.pipeline import Pipeline
from sklearn.model_selection import cross_validate
from sklearn.feature_selection import SelectKBest
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.model_selection import cross_validate
from sklearn.preprocessing import OneHotEncoder , RobustScaler
from category_encoders import BinaryEncoder , OrdinalEncoder
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.svm import SVR
from xgboost import XGBRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.neural_network import MLPRegressor
from sklearn.linear_model import LogisticRegression
from xgboost import XGBClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.naive_bayes import MultinomialNB , GaussianNB
from sklearn.svm import SVC 
from sklearn.impute import SimpleImputer , KNNImputer

# %%
x = df.drop("Loan_Status" , axis = 1 )
y = df["Loan_Status"]

# %%
x.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Gender             601 non-null    object
#  1   Married            611 non-null    object
#  2   Dependents         599 non-null    object
#  3   Education          614 non-null    object
#  4   Self_Employed      582 non-null    object
#  5   ApplicantIncome    614 non-null    int64
#  6   CoapplicantIncome  614 non-null    float64
#  7   LoanAmount         592 non-null    float64
#  8   Loan_Amount_Term   600 non-null    float64
#  9   Credit_History     564 non-null    float64
#  10  Property_Area      614 non-null    object
# dtypes: float64(4), int64(1), object(6)
# memory usage: 52.9+ KB

# %%
Num_Columns = x.select_dtypes(include="number")
Cat_Columns = x.select_dtypes(include="object_")

# %%
Num_Steps = list()
Num_Steps.append(("Num_Imputer" , KNNImputer()))
Num_Steps.append(("Scaler" , StandardScaler()))
Num_Pipeline = Pipeline(steps=Num_Steps)

# %%
Cat_Steps = list()
Cat_Steps.append(("Cat_Imputer" , SimpleImputer(strategy='most_frequent')))
Cat_Steps.append(("Cat_Encoder" , OneHotEncoder(sparse=False , drop='first')))
Cat_Pipeline = Pipeline(steps= Cat_Steps)

# %%
Transformer = ColumnTransformer(transformers=[('Num' , Num_Pipeline , Num_Columns.columns) , ('Cat' , Cat_Pipeline , Cat_Columns.columns) ] , remainder='passthrough')

# %%
steps = list()
steps.append(("Preprocessing" , Transformer))
steps.append(("Model" , LogisticRegression()))
pipeline = Pipeline(steps=steps)

# %%
results = cross_validate(pipeline , x , y , scoring="accuracy"  ,cv = 5 , return_train_score=True)

# %%
results["train_score"].mean()
# Out:
# 0.8110757869289488

# %%
results["test_score"].mean()
# Out:
# 0.8062375049980007

# %%
models = list()

models.append(("LR" , LogisticRegression()))
models.append(("GNB" , GaussianNB()))
models.append(("SVM" , SVC()))
models.append(("KNN" , KNeighborsClassifier()))
models.append(("RF" , RandomForestClassifier()))
models.append(("XG" , XGBClassifier()))
models.append(("DT" , DecisionTreeClassifier()))

# %%
for model in models:
    steps = list()
    steps.append(("Preprocessing" , Transformer))
    steps.append(model)
    pipeline = Pipeline(steps = steps)
    scores = cross_validate(pipeline , x , y , scoring="accuracy"  ,cv = 5 , return_train_score=True)
    print(model[0])
    print("Train_accuracy" , scores["train_score"].mean() )
    print("-" * 10)
    print("Test_accuracy" , scores["test_score"].mean())
    print("-" * 20)
    print("\n")
# Out:
# LR
# Train_accuracy 0.8110757869289488
# ----------
# Test_accuracy 0.8062375049980007
# --------------------
#
#
# GNB
# Train_accuracy 0.8013014753365455
# ----------
# Test_accuracy 0.7818072770891643
# --------------------
#
#
# SVM
# Train_accuracy 0.8277664630006789
# ----------
# Test_accuracy 0.7980407836865254
# --------------------
#
#
# KNN
# Train_accuracy 0.8355041147152816
# ----------
# Test_accuracy 0.7703851792616287
# --------------------
# /opt/anaconda3/lib/python3.9/site-packages/sklearn/neighbors/_classification.py:237: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
# ...

# %%
steps = list()
steps.append(("Preprocessing" , Transformer))
steps.append(("SVM" , SVC()))
pipeline = Pipeline(steps = steps)
scores = cross_validate(pipeline , x , y , scoring="accuracy"  ,cv = 5 , return_train_score=True,return_estimator=True)
print("Train_accuracy" , scores["train_score"].mean() )
print("-" * 10)
print("Test_accuracy" , scores["test_score"].mean())
print("-" * 20)
print("\n")
# Out:
# Train_accuracy 0.8277664630006789
# ----------
# Test_accuracy 0.7980407836865254
# --------------------

# %%
pipeline["SVM"].get_params()
# Out:
# {'C': 1.0,
#  'break_ties': False,
#  'cache_size': 200,
#  'class_weight': None,
#  'coef0': 0.0,
#  'decision_function_shape': 'ovr',
#  'degree': 3,
#  'gamma': 'scale',
#  'kernel': 'rbf',
#  'max_iter': -1,
#  'probability': False,
#  'random_state': None,
#  'shrinking': True,
#  'tol': 0.001,
#  'verbose': False}

# %%
from sklearn.model_selection import GridSearchCV
params = [
        {'SVM__C':[0.5,1,2,3,5], 'SVM__kernel':['linear', 'sigmoid', 'poly']},
        {'SVM__C':[0.5,1,2,3,5], 'SVM__kernel':['rbf'], 'SVM__gamma':[0.5, 0.6, 0.7, 0.1, 0.01, 0.05,"scale"]},
        {'SVM__C':[0.5,1,2,3,5], 'SVM__kernel':['poly'] , "SVM__degree" :[2,3,4,5]},
         ]

# %%
steps = list()
steps.append(("Preprocessing" , Transformer))
steps.append(("SVM" , SVC()))
pipeline = Pipeline(steps = steps)

# %%
grid_search = GridSearchCV(estimator=pipeline,
                           param_grid=params,
                           scoring='accuracy',
                           cv=5, n_jobs=-1,return_train_score=True)
grid_search.fit(x, y)
# Out:
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('Preprocessing',
#                                         ColumnTransformer(remainder='passthrough',
#                                                           transformers=[('Num',
#                                                                          Pipeline(steps=[('Num_Imputer',
#                                                                                           KNNImputer()),
#                                                                                          ('Scaler',
#                                                                                           StandardScaler())]),
#                                                                          Index(['ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History'],
#       dtype='object')),
#                                                                         ('Cat',
# ...

# %%
grid_search.cv_results_["mean_test_score"].mean()
# Out:
# 0.7898783343805336

# %%
grid_search.cv_results_["mean_train_score"].mean()
# Out:
# 0.8427759130078938

# %%
grid_search.best_estimator_
# Out:
# Pipeline(steps=[('Preprocessing',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('Num',
#                                                   Pipeline(steps=[('Num_Imputer',
#                                                                    KNNImputer()),
#                                                                   ('Scaler',
#                                                                    StandardScaler())]),
#                                                   Index(['ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History'],
#       dtype='object')),
#                                                  ('Cat',
#                                                   Pipeline(steps=[('Cat_Imputer',
#                                                                    SimpleImputer(strategy='most_frequent')),
# ...

# %%
from imblearn.pipeline import Pipeline as ImPipeline
from imblearn.combine import SMOTETomek
from imblearn.over_sampling import SMOTE
from imblearn.under_sampling import TomekLinks

# %%
y.sum()
# Out:
# 422

# %%
len(y)
# Out:
# 614

# %%
steps = list()
steps.append(("Preprocessing" , Transformer))
steps.append(("SmoteTomek" , SMOTETomek(smote=SMOTE(sampling_strategy={0:220} , random_state=24))))
steps.append(("SVM" , SVC()))
pipeline = ImPipeline(steps = steps)
scores = cross_validate(pipeline , x , y , scoring="accuracy"  ,cv = 5 , return_train_score=True,return_estimator=True)
print("Train_accuracy" , scores["train_score"].mean() )
print("-" * 10)
print("Test_accuracy" , scores["test_score"].mean())
# Out:
# Train_accuracy 0.8289884589273591
# ----------
# Test_accuracy 0.7964147674263627

# %%
pipeline.fit(x,y)
# Out:
# Pipeline(steps=[('Preprocessing',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('Num',
#                                                   Pipeline(steps=[('Num_Imputer',
#                                                                    KNNImputer()),
#                                                                   ('Scaler',
#                                                                    StandardScaler())]),
#                                                   Index(['ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History'],
#       dtype='object')),
#                                                  ('Cat',
#                                                   Pipeline(steps=[('Cat_Imputer',
#                                                                    SimpleImputer(strategy='most_frequent')),
# ...

# %%
import joblib

# %%
joblib.dump(pipeline , "Models3.pkl")
joblib.dump(x.columns,"Inputs3.pkl")
# Out:
# ['Inputs.pkl']

# %%
x.columns
# Out:
# Index(['Gender', 'Married', 'Dependents', 'Education', 'Self_Employed',
#        'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History', 'Property_Area'],
#       dtype='object')

# %%
x["Loan_Amount_Term"].describe()
# Out:
# count    600.00000
# mean     342.00000
# std       65.12041
# min       12.00000
# 25%      360.00000
# 50%      360.00000
# 75%      360.00000
# max      480.00000
# Name: Loan_Amount_Term, dtype: float64

# %%
# %%writefile Streamlit3_app.py

import joblib
import pandas as pd
import numpy as np
import streamlit as st

Model = joblib.load("Third_Group.pkl")
Inputs = joblib.load("inputs.pkl")

def prediction(Gender,Married,Dependents,Education,Self_Employed,LoanAmount,Loan_Amount_Term,Credit_History,Property_Area):
    df = pd.DataFrame(columns=Inputs)
    df.at[0,"Gender"] = Gender
    df.at[0,"Married"] = Married
    df.at[0,"Dependents"] = Dependents
    df.at[0,"Education"] = Education
    df.at[0,"Self_Employed"] = Self_Employed
    df.at[0,"LoanAmount"] = LoanAmount
    df.at[0,"Loan_Amount_Term"] = Loan_Amount_Term
    df.at[0,"Credit_History"] = Credit_History
    df.at[0,"Property_Area"] = Property_Area
    
    result = Model.predict(df)[0]
    return result

def Main():
    st.title("Loan Prediction")
    Gender = st.selectbox("Gender",['Male', 'Female'])
    Married = st.selectbox("Married",['No', 'Yes'])
    Dependents = st.selectbox("Dependents",[ '0',  '1',  '2',  '3'])
    Education = st.selectbox("Education",['Graduate', 'Not Graduate'])
    Self_Employed = st.selectbox("Self_Employed",['No', 'Yes'])
    LoanAmount = st.slider("LoanAmount in Thousands",min_value=9.0 , max_value=700.0 , step=1.0,value = 10.0)
    Loan_Amount_Term = st.slider("Loan_Amount_Term",min_value=12.0 , max_value=480.0 , step=1.0,value = 10.0)
    Credit_History = st.selectbox("Credit_History",[1, 0])
    Property_Area = st.selectbox("Property_Area",['Urban', 'Rural', 'Semiurban'])
    ApplicantIncome = st.slider("ApplicantIncome",min_value=0.0 , max_value=81000.0 , step=5.0,value = 500.0)
    CoapplicantIncome = st.slider("CoapplicantIncome",min_value=0.0 , max_value= 41667.0 , step=5.0,value = 500.0)
    
    
    if st.button("Predict"):
        result = prediction(Gender,Married,Dependents,Education,Self_Employed,LoanAmount,Loan_Amount_Term,Credit_History,Property_Area)
        list_result = ["Rejected" , "Accepted"]
        st.text(f"Your loan is {list_result[result]}")
Main()
# Out:
# Overwriting Streamlit3_app.py
